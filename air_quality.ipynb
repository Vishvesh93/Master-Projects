# %%
import pandas as pd
import numpy as np
from pandas import Series
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
ib18 = pd.read_excel('ihbas_2018.xlsx')

# %%
ib13 = pd.read_excel('ihbas_2013.xlsx')

# %%
ib14 = pd.read_excel('ihbas_2014.xlsx')

# %%
ib18.head()
# Out:
#           From Date    NO2 CO   PM2.5     NH3    SO2 PM2.5_1  NH3_1  SO2_1  \
# 0  01-01-2018 00:00  45.68  0  248.92  118.49  36.38  115.92  55.91  20.84
# 1  01-01-2018 01:00   34.9  0  241.68  108.06   42.3  115.15  58.03  15.63
# 2  01-01-2018 02:00  29.02  0  246.35   89.78  45.02  116.53  55.13   8.04
# 3  01-01-2018 03:00  20.37  0  204.65   52.75  41.43     114  51.27  11.26
# 4  01-01-2018 04:00  32.71  0  145.67    48.1   39.8   113.7  44.53  16.76
#
#       CO_1  NO2_1
# 0   1016.7  63.57
# 1   1679.3  44.74
# 2  1215.97  37.79
# 3   808.28   36.4
# 4   311.82  30.27

# %%
ib14.head()

# %%
ib18.info()

# %%
ib14.info()

# %%
ib18['Date'] = pd.to_datetime(ib18['From Date'], format= '%d-%m-%Y %H:%M')

# %%
ib18.set_index(ib18['Date'], inplace= True)

# %%
ib18.drop('From Date', axis=1, inplace= True)

# %%
ib18.replace(to_replace= 'None', value=0, inplace= True)

# %%
ib18['PM2.5'].plot(linewidth = 0.5)

# %%
import plotly as py
import plotly.graph_objs as go

py.offline.init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
py.offline.init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
data = [go.Scatter(
          x=ib18['From Date'],
          y=ib18['CO'])]

py.offline.iplot(data)
# Out:
# <div id="cdddf30e-49b1-4a08-9068-a26ccc597906" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cdddf30e-49b1-4a08-9068-a26ccc597906", [{"x": ["01-01-2018 00:00", "01-01-2018 01:00", "01-01-2018 02:00", "01-01-2018 03:00", "01-01-2018 04:00", "01-01-2018 05:00", "01-01-2018 06:00", "01-01-2018 07:00", "01-01-2018 08:00", "01-01-2018 09:00", "01-01-2018 10:00", "01-01-2018 11:00", "01-01-2018 12:00", "01-01-2018 13:00", "01-01-2018 14:00", "01-01-2018 15:00", "01-01-2018 16:00", "01-01-2018 17:00", "01-01-2018 18:00", "01-01-2018 19:00", "01-01-2018 20:00", "01-01-2018 21:00", "01-01-2018 22:00", "01-01-2018 23:00", "02-01-2018 00:00", "02-01-2018 01:00", "02-01-2018 02:00", "02-01-2018 03:00", "02-01-2018 04:00", "02-01-2018 05:00", "02-01-2018 06:00", "02-01-2018 07:00", "02-01-2018 08:00", "02-01-
# ...

# %%
trace1 = go.Scatter(
          x=ib18['From Date'],
          y=ib18['PM2.5'],
        name = "2013",
        opacity = 0.8)

# %%
data = [trace1]
py.offline.iplot(data)
# Out:
# <div id="a5255370-2728-4131-9d73-4a766f97fc12" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a5255370-2728-4131-9d73-4a766f97fc12", [{"name": "2013", "opacity": 0.8, "x": ["01-01-2018 00:00", "01-01-2018 01:00", "01-01-2018 02:00", "01-01-2018 03:00", "01-01-2018 04:00", "01-01-2018 05:00", "01-01-2018 06:00", "01-01-2018 07:00", "01-01-2018 08:00", "01-01-2018 09:00", "01-01-2018 10:00", "01-01-2018 11:00", "01-01-2018 12:00", "01-01-2018 13:00", "01-01-2018 14:00", "01-01-2018 15:00", "01-01-2018 16:00", "01-01-2018 17:00", "01-01-2018 18:00", "01-01-2018 19:00", "01-01-2018 20:00", "01-01-2018 21:00", "01-01-2018 22:00", "01-01-2018 23:00", "02-01-2018 00:00", "02-01-2018 01:00", "02-01-2018 02:00", "02-01-2018 03:00", "02-01-2018 04:00", "02-01-2018 05:00", "02-01-2018 06:00", "02-01-2018 07:
# ...

# %%
av_2017['To_Date'] = pd.to_datetime(av_2017['To Date'], dayfirst=True)

# %%
av_2017[av_2017['To Date'] == ' '].count()

# %%
av_2017.info()
